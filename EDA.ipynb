# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime
# %matplotlib inline
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Importing data

# %%
books = pd.read_csv("/Users/sonalsharma/Desktop/Fall2021/Data 228 We/Project/BRS_Trial/dataset_brs/books.csv")

tags_data = pd.read_csv("/Users/sonalsharma/Desktop/Fall2021/Data 228 We/Project/BRS_Trial/dataset_brs/book_tags.csv")

book_tags = pd.read_csv("/Users/sonalsharma/Desktop/Fall2021/Data 228 We/Project/BRS_Trial/dataset_brs/tags.csv")

ratings_data=pd.read_csv('/Users/sonalsharma/Desktop/Fall2021/Data 228 We/Project/BRS_Trial/dataset_brs/ratings.csv')

# %%
ratings_data = ratings_data.sort_values("user_id")
ratings_data.drop_duplicates(subset =["user_id","book_id"], keep = False, inplace = True)

# %%
books= books.drop(columns=['book_id', 'best_book_id', 'work_id', 'isbn', 'isbn13', 'title','work_ratings_count',
                                   'work_text_reviews_count', 'ratings_1', 'ratings_2', 'ratings_3', 'ratings_4', 'ratings_5', 
                                    'image_url','small_image_url'])

# %%
books = books.dropna()
books.drop_duplicates(subset='original_title',keep=False,inplace=True)

# %% [markdown]
# # Top Rated Books

# %%
top_rated = books.sort_values('average_rating', ascending=False)
tf_top_rated = top_rated[:15]
sns.set_theme(style = "whitegrid")
ax = sns.barplot(  x="average_rating", y="original_title",  data = tf_top_rated ).set(title = 'Top Rated Books')

# %% [markdown]
# # Average Ratings of Books

# %%
plt.figure(figsize = (12 , 6))
plt.title(" Average Ratings of Books")
books["average_rating"].hist()
display()
